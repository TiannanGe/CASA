# %% [markdown]
# 向量 Vector : c()
# 矩阵 Matrix: matrix()
# 数据框 DataFrame: data.frame()
#
# x1 =c(1,2,3,4) #创建向量x1
# length(x1) #x1的长度
# mode(x1) #查看数据类型,主要分为numeric和character类型
# x1=c(1;100) #创建1-100的向量
# rbind(x1,x2) #将两组向量合并成一个横向矩阵
# cbind(x1,x2) #将两组向量合并成一个纵向矩阵
#
# x=c(1:100) #创建向量1到100
# x[5] #显示向量里的第五个元素
# x[-5] #除第五个元素不显示外,其他都显示
# mean(x) #求其平均值
# sum(x) #求和
# var(x) #求方差,反应数据离散情况,方差越大离散越高
# median() #求中位数
# quantile() #百分位数
# prod(x) #联乘
# sd(x) #标准差,方差再开方
# seq(5,121,by=2) #创建一个公差为2,从5到121的向量
# seq(5,121,length=10) #创建总共十个,从5到121的向量
# which.max(x) #取最大值最小值等等,返回下标
# rev(x) #颠倒向量
# sort(x) #从新排序向量
#
# x1=c(1:12) #创建向量1到12
# matrix(x1,nrow=3,ncol=4) #生成矩阵,三行四列
# t(x1) #矩阵转置
# x1%*%x2 #矩阵相乘
# diag(x) #求对角线
# Data1 <- rnorm(100, mean = 53, sd=34) #定义一个向量data1,生成100个正态分布的随机数,平均是53,标准差34
# a=mmatrix(rnorm(16),4,4) #定义一个叫a的4X4矩阵,内容是正态分布产生16个随机数
# solve(a,b) #解方程
# eigen() #求特征值
# x=data.frame(x1,x2) #将x1x2组成数据框
# plot(x) #画图命令,散点图
# x=read.table("abc.txt") #读文本文件的命令
# while() #循环语句
# x1=round(runif(100,min=80,max=100)) #round函数为四舍五入,产生100个均匀分布的随机数,最大100,最小80
# x1=round(runif(100,mean=83,sd=18)) #产生100个正态分布随机数,平均值83,标准差18
# x1[which(x1>100)]=100 #将超过100分的变为100分
# x=data.frame(x1,x2) #将两个向量合并为一个数据框
# summary(df) #查看摘要数据
#
# hist() #画直方图
# pie() #画饼图
# boxplot() #画箱线图 ,中线为样本中位数,箱子上线和下线为25%和75%的分位数,延伸线为最高值最低值
# stars() #绘制星象图
# stem() #画茎叶图
# qqnorm() #qq图,查看数据是否正态分布
# qqline()
# main() #表标题
# xlab="xxx" #x轴标题
# xlim=c(1,100) #x轴尺度
# plot(a,b,type="l") #画出用点连成线的图
# dev.new() #新建一个图形窗口
# dev.cur() #显示当前图形窗口
#
# mycsv <- read_csv("路径.csv"")   #定义一个叫mycsv的csv文件并加载
# rm(A) #删除对象A
#
# dplyr::filter() #dplyr中filter函数, 用于过滤筛选
# LondonBoroughs %>%
#   dplyr::select(`Ward name`) %>%
#   print()
#
#   dplyr::select() #选择指定数据列

# %% [markdown]
# #R求平均数
# numbers = c(1, 4, 7, 6, 4, 2)
# total   = 0
# count   = 0
# for (num in numbers) {
#   total = total + num
#   count = count + 1
# }
# mean = total / count
# print(mean)
